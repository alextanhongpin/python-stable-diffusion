# %%
# !nvidia-smi
# Out:
# Tue Mar 21 15:54:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    25W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
https://keras.io/guides/keras_cv/generate_images_with_stable_diffusion/

# %%
# !pip install --upgrade -qq keras-cv

# %%
import keras_cv
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# You do not have Waymo Open Dataset installed, so KerasCV Waymo metrics are not available.

# %%
model = keras_cv.models.StableDiffusion(img_width=512, img_height=512)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
images = model.text_to_image("photograph of an astronaut riding a horse", batch_size=3)


def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")


plot_images(images)
# Out:
# ...
# 492466864/492466864 [==============================] - 4s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# ...
# 198180272/198180272 [==============================] - 1s 0us/step

# %%
# %%timeit
images = model.text_to_image("cat with a laptop, studio ghibli, emotional damage, soft colors", batch_size=3)


def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")


plot_images(images)
# Out:
# 50/50 [==============================] - 119s 2s/step

# %%
# %%time
images = model.text_to_image("persian cat programming with a laptop, emotional damage, splash of colors, realistic, character concept, quality art, digital painting", batch_size=3)


def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")


plot_images(images)
# Out:
# 50/50 [==============================] - 123s 2s/step
# CPU times: user 1min 27s, sys: 29.8 s, total: 1min 57s
# Wall time: 2min 5s

# %%
# %%time
images = model.text_to_image("grumpy cat coding on a laptop, splash of colors, realistic, character concept, quality art, digital painting, splash of color, artistic", batch_size=3)


def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")


plot_images(images)
# Out:
# 50/50 [==============================] - 120s 2s/step
# CPU times: user 1min 27s, sys: 31 s, total: 1min 58s
# Wall time: 2min 2s
